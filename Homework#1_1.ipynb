# %%
import pandas as pd
df=pd.read_csv('nba_data.csv')
df.shape
# Out:
# (155713, 51)

# %%
df.head(15)
# Out:
#         gmDate gmTime  seasTyp    playLNm   playFNm teamAbbr teamConf  \
# 0   2012-10-30  19:00  Regular      Price      A.J.      WAS     East
# 1   2012-10-30  19:00  Regular      Ariza    Trevor      WAS     East
# 2   2012-10-30  19:00  Regular     Okafor     Emeka      WAS     East
# 3   2012-10-30  19:00  Regular       Beal   Bradley      WAS     East
# 4   2012-10-30  19:00  Regular     Booker    Trevor      WAS     East
# 5   2012-10-30  19:00  Regular   Crawford    Jordan      WAS     East
# 6   2012-10-30  19:00  Regular    Webster   Martell      WAS     East
# 7   2012-10-30  19:00  Regular     Vesely       Jan      WAS     East
# 8   2012-10-30  19:00  Regular  Singleton     Chris      WAS     East
# 9   2012-10-30  19:00  Regular     Barron      Earl      WAS     East
# 10  2012-10-30  19:00  Regular      Pargo   Jannero      WAS     East
# 11  2012-10-30  19:00  Regular    Varejao  Anderson      CLE     East
# 12  2012-10-30  19:00  Regular     Irving     Kyrie      CLE     East
# 13  2012-10-30  19:00  Regular        Gee    Alonzo      CLE     East
# 14  2012-10-30  19:00  Regular   Thompson   Tristan      CLE     East
#
#       teamDiv teamLoc teamRslt  ...  playFT% playORB playDRB playTRB opptAbbr  \
# 0   Southeast    Away     Loss  ...     1.00       1       1       2      CLE
# 1   Southeast    Away     Loss  ...     0.50       1       2       3      CLE
# 2   Southeast    Away     Loss  ...     0.50       5       2       7      CLE
# 3   Southeast    Away     Loss  ...     1.00       0       3       3      CLE
# 4   Southeast    Away     Loss  ...     0.00       1       0       1      CLE
# 5   Southeast    Away     Loss  ...     0.75       1       2       3      CLE
# 6   Southeast    Away     Loss  ...     0.00       0       3       3      CLE
# 7   Southeast    Away     Loss  ...     0.25       3       1       4      CLE
# 8   Southeast    Away     Loss  ...     0.00       2       2       4      CLE
# 9   Southeast    Away     Loss  ...     0.00       4       4       8      CLE
# 10  Southeast    Away     Loss  ...     1.00       0       1       1      CLE
# 11    Central    Home      Win  ...     1.00      12      11      23      WAS
# 12    Central    Home      Win  ...     0.80       0       6       6      WAS
# 13    Central    Home      Win  ...     0.00       2       1       3      WAS
# 14    Central    Home      Win  ...     0.50       3       7      10      WAS
#
#    opptConf    opptDiv opptLoc opptRslt  opptDayOff
# 0      East    Central    Home      Win           0
# 1      East    Central    Home      Win           0
# 2      East    Central    Home      Win           0
# 3      East    Central    Home      Win           0
# 4      East    Central    Home      Win           0
# 5      East    Central    Home      Win           0
# 6      East    Central    Home      Win           0
# 7      East    Central    Home      Win           0
# 8      East    Central    Home      Win           0
# 9      East    Central    Home      Win           0
# 10     East    Central    Home      Win           0
# 11     East  Southeast    Away     Loss           0
# 12     East  Southeast    Away     Loss           0
# 13     East  Southeast    Away     Loss           0
# 14     East  Southeast    Away     Loss           0
#
# [15 rows x 51 columns]

# %%
import datetime as dt
import calendar 
# Function that calculates the day of week it is.for e.g.Day('2020-07-19')=Sunday
def Day(date): 
    born = dt.datetime.strptime(date,'%Y-%m-%d').weekday() 
    return (calendar.day_name[born])

# %%
Day('2020-07-19')
# Out:
# 'Sunday'

# %%
df['Day_of_week']=df['gmDate'].apply(findDay)

# %%
df.head(15)
# Out:
#         gmDate gmTime  seasTyp    playLNm   playFNm teamAbbr teamConf  \
# 0   2012-10-30  19:00  Regular      Price      A.J.      WAS     East
# 1   2012-10-30  19:00  Regular      Ariza    Trevor      WAS     East
# 2   2012-10-30  19:00  Regular     Okafor     Emeka      WAS     East
# 3   2012-10-30  19:00  Regular       Beal   Bradley      WAS     East
# 4   2012-10-30  19:00  Regular     Booker    Trevor      WAS     East
# 5   2012-10-30  19:00  Regular   Crawford    Jordan      WAS     East
# 6   2012-10-30  19:00  Regular    Webster   Martell      WAS     East
# 7   2012-10-30  19:00  Regular     Vesely       Jan      WAS     East
# 8   2012-10-30  19:00  Regular  Singleton     Chris      WAS     East
# 9   2012-10-30  19:00  Regular     Barron      Earl      WAS     East
# 10  2012-10-30  19:00  Regular      Pargo   Jannero      WAS     East
# 11  2012-10-30  19:00  Regular    Varejao  Anderson      CLE     East
# 12  2012-10-30  19:00  Regular     Irving     Kyrie      CLE     East
# 13  2012-10-30  19:00  Regular        Gee    Alonzo      CLE     East
# 14  2012-10-30  19:00  Regular   Thompson   Tristan      CLE     East
#
#       teamDiv teamLoc teamRslt  ...  playORB playDRB playTRB opptAbbr  \
# 0   Southeast    Away     Loss  ...        1       1       2      CLE
# 1   Southeast    Away     Loss  ...        1       2       3      CLE
# 2   Southeast    Away     Loss  ...        5       2       7      CLE
# 3   Southeast    Away     Loss  ...        0       3       3      CLE
# 4   Southeast    Away     Loss  ...        1       0       1      CLE
# 5   Southeast    Away     Loss  ...        1       2       3      CLE
# 6   Southeast    Away     Loss  ...        0       3       3      CLE
# 7   Southeast    Away     Loss  ...        3       1       4      CLE
# 8   Southeast    Away     Loss  ...        2       2       4      CLE
# 9   Southeast    Away     Loss  ...        4       4       8      CLE
# 10  Southeast    Away     Loss  ...        0       1       1      CLE
# 11    Central    Home      Win  ...       12      11      23      WAS
# 12    Central    Home      Win  ...        0       6       6      WAS
# 13    Central    Home      Win  ...        2       1       3      WAS
# 14    Central    Home      Win  ...        3       7      10      WAS
#
#    opptConf    opptDiv opptLoc opptRslt opptDayOff  Day_of_week
# 0      East    Central    Home      Win          0      Tuesday
# 1      East    Central    Home      Win          0      Tuesday
# 2      East    Central    Home      Win          0      Tuesday
# 3      East    Central    Home      Win          0      Tuesday
# 4      East    Central    Home      Win          0      Tuesday
# 5      East    Central    Home      Win          0      Tuesday
# 6      East    Central    Home      Win          0      Tuesday
# 7      East    Central    Home      Win          0      Tuesday
# 8      East    Central    Home      Win          0      Tuesday
# 9      East    Central    Home      Win          0      Tuesday
# 10     East    Central    Home      Win          0      Tuesday
# 11     East  Southeast    Away     Loss          0      Tuesday
# 12     East  Southeast    Away     Loss          0      Tuesday
# 13     East  Southeast    Away     Loss          0      Tuesday
# 14     East  Southeast    Away     Loss          0      Tuesday
#
# [15 rows x 52 columns]
